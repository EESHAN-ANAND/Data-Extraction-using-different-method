# %% [markdown]
# the url used is:-https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1

# %%
import pandas as pd
import requests

# %%
responce=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=<<api_key>>&language=en-US&page=1")

# %%
pd.DataFrame(responce.json()["results"])
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /ejniJnlOdtSgtbh8D7u2RxT6Uli.jpg                 [35, 14]  772071
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg                 [18, 80]     238
# 2   False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg                 [18, 80]     278
# 3   False  /wxaBkuqVIgImjRHEMJoxL9Lq6i8.jpg      [16, 10751, 12, 14]  995133
# 4   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg                 [18, 80]     240
# 5   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg          [18, 36, 10752]     424
# 6   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg          [35, 18, 10749]   19404
# 7   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg          [16, 10751, 14]     129
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                     [18]     389
# 9   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg          [10749, 16, 18]  372058
# 10  False  /tGwO4xcBjhXC0p5qlkw37TrH6S6.jpg  [16, 12, 35, 10751, 14]  315162
# ...

# %%
pd.DataFrame(responce.json()["results"]).head(2)
# Out:
#    adult                     backdrop_path genre_ids      id  \
# 0  False  /ejniJnlOdtSgtbh8D7u2RxT6Uli.jpg  [35, 14]  772071
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]     238
#
#   original_language    original_title  \
# 0                es  Cuando Sea Joven
# 1                en     The Godfather
#
#                                             overview  popularity  \
# 0  70-year-old Malena gets a second chance at lif...      65.248
# 1  Spanning the years 1945 to 1955, a chronicle o...      98.417
#
#                         poster_path release_date             title  video  \
# 0  /6gIJuFHh5Lj4dNaPG3TzIMl7L68.jpg   2022-09-14  Cuando Sea Joven  False
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14     The Godfather  False
#
#    vote_average  vote_count
# 0           8.8         200
# 1           8.7       17445

# %%
pd.DataFrame(responce.json()["results"]).columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
pd.DataFrame(responce.json()["results"]).head(2)[["id","title","overview","release_date","popularity","vote_average","vote_count"]]
# Out:
#        id             title  \
# 0  772071  Cuando Sea Joven
# 1     238     The Godfather
#
#                                             overview release_date  popularity  \
# 0  70-year-old Malena gets a second chance at lif...   2022-09-14      65.248
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      98.417
#
#    vote_average  vote_count
# 0           8.8         200
# 1           8.7       17445

# %%
#now o know that this is the information from a single page but i want to gather information from the multiple page
df=pd.DataFrame()
for i in range(1,4): #lets say i want to get first 3 pages
  responce_i=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(i))
  dfi=pd.DataFrame(responce_i.json()["results"])
  df=df.append(dfi, ignore_index=True)

# %%
df
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /ejniJnlOdtSgtbh8D7u2RxT6Uli.jpg                 [35, 14]  772071
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg                 [18, 80]     238
# 2   False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg                 [18, 80]     278
# 3   False  /wxaBkuqVIgImjRHEMJoxL9Lq6i8.jpg      [16, 10751, 12, 14]  995133
# 4   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg                 [18, 80]     240
# 5   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg          [18, 36, 10752]     424
# 6   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg          [35, 18, 10749]   19404
# 7   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg          [16, 10751, 14]     129
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                     [18]     389
# 9   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg          [10749, 16, 18]  372058
# 10  False  /tGwO4xcBjhXC0p5qlkw37TrH6S6.jpg  [16, 12, 35, 10751, 14]  315162
# ...

# %%
import pandas as pd
import requests
df=pd.DataFrame()
for i in range(1,5):
  responce=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(i))
  data=pd.DataFrame(responce.json()['results'])
  df=df.append(data, ignore_index=True)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
